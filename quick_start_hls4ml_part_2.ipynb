# %% [markdown]
# # dfx4ml quick start — Part 2 (`config_4`: 2 PR regions, 4 RMs)
#
# **Target board: Xilinx KV260** (Zynq UltraScale+, Vivado/Vitis 2023.2, Ubuntu 22.04 + PYNQ).
#
# End-to-end Keras → hls4ml → dfx4ml build for the **4-partition** topology (`part1`..`part4` across two reconfigurable regions, 2 RMs each).
#
# Run from the **repo root**. The model + weight/input lock are built by `build_quick_start_model()` in `example/tutorial/quick_start_hls4ml_model.py`; this notebook covers everything from the topology `CONFIG` through the hardware + software build, and stages the data the board test notebook (`hls4ml_2_region_4_rm.ipynb`) needs. The final cell copies the packaged project to the KV260.

# %% [markdown]
# ## 1. Environment + backend
# Add `lib/` and the `hls4ml` submodule to the path, register the dfx4ml backend, and import the build helpers.

# %%
import os, sys, json, shutil
from pathlib import Path

REPO = Path.cwd()                                # run this notebook from the repo root
sys.path.insert(0, str(REPO / 'lib'))            # lib/hls4ml_build + lib/hls4ml_con
sys.path.insert(0, str(REPO / 'hls4ml'))         # hls4ml submodule source
os.environ['HLS4ML_BACKEND_PLUGINS'] = 'hls4ml_con'   # discovered at `import hls4ml`
os.environ.setdefault('TF_CPP_MIN_LOG_LEVEL', '3')

import numpy as np
import hls4ml
from hls4ml_build import Hls4ml_build, Partition, Stream, DMA   # orchestrator + typed topology
from lib.hw_build import HwBuildHelper
from lib.sw_build import SwBuildHelper

assert 'vitisunifieddfx4ml' in hls4ml.backends.get_available_backends(), \
    'VitisUnifiedDFx4ml backend not registered — check HLS4ML_BACKEND_PLUGINS / sys.path'
print('OK: VitisUnifiedDFx4ml registered')
# Out:
# OK: VitisUnifiedDFx4ml registered

# %% [markdown]
# ## 2. Load the model
# The Keras model, shared-weight partition sub-models, locked input pool, and probe list come from `build_quick_start_model()` in `example/tutorial/quick_start_hls4ml_model.py`. It is idempotent — the first call trains + locks the weights/input pool to `OUT_ROOT/_lock`; later calls reload them, so results are identical run-to-run.

# %%
# the trained full model, the partition sub-models (shared weights), the locked input
# pool and the per-layer probe list all come from
# example/tutorial/quick_start_hls4ml_model.py. build_quick_start_model() is idempotent:
# the first call trains + locks the weights / input pool to OUT_ROOT/_lock; every later
# call (even after a kernel restart, or if _lock was deleted) re-creates / re-loads them,
# so the csim / diag numbers are identical run-to-run.
sys.path.insert(0, str(REPO / 'example' / 'tutorial'))
from quick_start_hls4ml_model import build_quick_start_model

_m = build_quick_start_model()
full_model, halfA, halfB                 = _m.full_model, _m.halfA, _m.halfB
part1, part2, part3, part4               = _m.part1, _m.part2, _m.part3, _m.part4
X_pool, PROBE_LAYERS, OUT_ROOT, LOCK_DIR = _m.X_pool, _m.PROBE_LAYERS, _m.OUT_ROOT, _m.LOCK_DIR
print('model + locked input pool loaded; pool =', X_pool.shape)
# Out:
# full model params: 12532
# [lock] weights loaded ← /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/_lock/full_weights.h5
# partition models: ['full', 'halfA', 'halfB', 'part1', 'part2', 'part3', 'part4']
# [lock] loaded 1,000 samples ← /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/_lock/x_input_pool.npy
# model + locked input pool loaded; pool = (1000, 8, 8, 1)

# %% [markdown]
# ## 3. Tool paths
# **Edit the two paths below** to point at *your* Vitis / Vivado 2023.2 installs (the dirs that hold `settings64.sh`). The defaults (`/tools/Xilinx/...`) are placeholders — change them if your tools live elsewhere.

# %%
# >>> EDIT THESE <<< Vitis / Vivado 2023.2 install dirs (each holds settings64.sh);
# Hls4ml_build.setup_env() sources them onto PATH at construction. Change them to match
# your machine if your Xilinx tools are not under /tools/Xilinx.
VITIS_PATH  = '/tools/Xilinx/Vitis/2023.2'
VIVADO_PATH = '/tools/Xilinx/Vivado/2023.2'

# %% [markdown]
# ## 4. Topology (`CONFIG`)
# The partition cut for this part — one `Partition` per (region, rm).

# %%
PART_TAG = 'part_2'      # output root / build_prj / export suffix for this part

# config_4 — 4 partitions across 2 PR regions (2 RMs each): part1/part3 share region 0,
# part2/part4 share region 1; streams are allocated/freed across phases 0–3.
CONFIG = [
    Partition('part1', 'p_part1', part1, region=0, inputs=[DMA], outputs=[
        Stream('a1',    region=0, alloc_phase=0, free_phase=1),
        Stream('skip1', region=1, alloc_phase=0, free_phase=2)]),
    Partition('part2', 'p_part2', part2, region=1, inputs=['a1'], outputs=[
        Stream('bneck', region=1, alloc_phase=1, free_phase=2),
        Stream('skip2', region=1, alloc_phase=1, free_phase=2)]),
    Partition('part3', 'p_part3', part3, region=0, rm=1, inputs=['bneck', 'skip2'], outputs=[
        Stream('p3',    region=0, alloc_phase=2, free_phase=3)]),
    Partition('part4', 'p_part4', part4, region=1, rm=1, inputs=['p3', 'skip1'], outputs=[DMA]),
]
print('config_4:', [p.name for p in CONFIG])
# Out:
# config_4: ['part1', 'part2', 'part3', 'part4']

# %% [markdown]
# ## 5. Run-stage toggles + build config
# Flip these to control which stages run. `RUN_DIAG` is optional. `AMT_QUERY` must match the board notebook.

# %%
# ── run-stage toggles ──────────────────────────────────────
RUN_CSIM    = True      # end-to-end csim across the partitions (saves x / y / pred)
RUN_DIAG    = False      # OPTIONAL per-layer HLS csim bisect (slow — see the diag cell below)
# C-synthesis stage — pick ONE (mutually exclusive). 'fifo' already runs C-synthesis as
# part of the FIFO-depth optimization, so it supersedes 'synth'; never run both.
#   'none'  — skip synthesis entirely
#   'synth' — C-synthesis + ip_catalog package (needs Vitis)
#   'fifo'  — C-synthesis + FIFO-depth optimization (needs Vitis cosim — heavy)
SYNTH_MODE  = 'fifo'
RUN_HWBUILD = True      # dfx4ml Vivado hardware + PYNQ software build

AMT_QUERY = 900         # csim sample count — must match the board notebook's AMT_QUERY

# per-part output root — keeps part_1 / part_2 artifacts from colliding (the shared
# weight/input lock still lives in OUT_ROOT/_lock; only the build outputs are split).
BUILD_ROOT = OUT_ROOT / PART_TAG

# shared Hls4ml_build construction config (everything except `partitions`)
HB_KW = dict(
    out_root       = BUILD_ROOT,
    board          = 'kv260',
    part           = 'xck26-sfvc784-2LV-c',
    clock_period   = '10ns',
    precision      = 'ap_fixed<16,6>',
    reuse_factor   = 8,
    strategy       = 'Resource',
    total_banks    = 64,
    rm_index_width = 3,
    vitis_path     = VITIS_PATH,
    vivado_path    = VIVADO_PATH,
)

# %% [markdown]
# ## 6. Construct the orchestrator

# %%
hb = Hls4ml_build(partitions=CONFIG, **HB_KW)
print('inferred: amt_phase =', hb.amt_phase, '| num_regions =', hb.num_regions)
# Out:
# v++       -> /tools/Xilinx/Vitis/2023.2/bin/v++
# vitis-run -> /tools/Xilinx/Vitis/2023.2/bin/vitis-run
# vivado    -> /tools/Xilinx/Vivado/2023.2/bin/vivado
# inferred: amt_phase = 3 | num_regions = 2

# %% [markdown]
# ## 7. Convert (get the partial model)

# %%
# 1. get the partial model — convert every partition to an hls4ml ModelGraph + firmware
hb.convert_all()
# Out:
# ================================================== convert part1
# WARNING: Invalid ReuseFactor=8 in layer "enc_conv1".Using ReuseFactor=9 instead. Valid ReuseFactor(s): 1,3,9,18,36,72.
# ================================================== convert part2
# ================================================== convert part3
# ================================================== convert part4
# converted: ['part1', 'part2', 'part3', 'part4']
# {'part1': <hls4ml.model.graph.ModelGraph at 0x7eee43432470>,
#  'part2': <hls4ml.model.graph.ModelGraph at 0x7eee1c2dc220>,
#  'part3': <hls4ml.model.graph.ModelGraph at 0x7eee1c160d30>,
#  'part4': <hls4ml.model.graph.ModelGraph at 0x7eee1c163f10>}

# %% [markdown]
# ## 8. csim + save reference data
# Runs the partitions end-to-end and saves `x_input.npy` / `y_keras.npy` / `y_pred_hls.npy` to `OUT_ROOT/_csim_data` (outside the partition dirs that convert wipes).

# %%
# 2. end-to-end csim + save the reference data the board test notebook expects.
# IMPORTANT: write to OUT_ROOT/_csim_data (a sibling of the partition project dirs) —
# convert_all / synth_all(fifo_opt=True) re-create OUT_ROOT/<partition>, so anything saved
# inside a partition folder would be wiped on a re-convert. _csim_data is never touched.
CSIM_DATA_DIR = BUILD_ROOT / '_csim_data'
CSIM_DATA_DIR.mkdir(parents=True, exist_ok=True)

if RUN_CSIM:
    X_csim     = X_pool[:AMT_QUERY].astype(np.float32)                 # x  — board input
    y_keras    = np.asarray(full_model.predict(X_csim), dtype=np.float32)  # y  — float ref
    final, bus = hb.csim_chain(x0=X_csim, peek=10)                     # HLS csim chained out
    y_pred_hls = np.asarray(final, dtype=np.float32)                   # pred — board 'expected'

    np.save(CSIM_DATA_DIR / 'x_input.npy',    X_csim)
    np.save(CSIM_DATA_DIR / 'y_keras.npy',    y_keras)
    np.save(CSIM_DATA_DIR / 'y_pred_hls.npy', y_pred_hls)
    print('saved ->', CSIM_DATA_DIR)
    print('  x_input.npy    ', X_csim.shape)
    print('  y_keras.npy    ', y_keras.shape)
    print('  y_pred_hls.npy ', y_pred_hls.shape)
# Out:
# 29/29 [==============================] - 0s 5ms/step
# ================================================================ part1
#   in  DMA      (900, 8, 8, 1) first10= [0.3745 0.9507 0.7320 0.5987 0.1560 0.1560 0.0581 0.8662 0.6011 0.7081]
#   out a1       (900, 256)     first10= [0.0000 0.0000 0.0000 0.0000 0.0127 0.0000 0.0459 0.0000 0.0039 0.0000]
#   out skip1    (900, 512)     first10= [0.0000 0.0000 0.0000 0.0000 0.3076 0.0000 0.0000 0.4561 0.0303 0.0898]
# ================================================================ part2
#   in  a1       (900, 256)     first10= [0.0000 0.0000 0.0000 0.0000 0.0127 0.0000 0.0459 0.0000 0.0039 0.0000]
#   out bneck    (900, 32)      first10= [0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000]
#   out skip2    (900, 256)     first10= [0.0117 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0107 0.0078]
# ================================================================ part3
#   in  bneck    (900, 32)      first10= [0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000]
#   in  skip2    (900, 256)     first10= [0.0117 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0107 0.0078]
#   out p3       (900, 256)     first10= [0.0000 0.0059 0.0000 0.0000 0.0029 0.0000 0.0059 0.0029 0.0000 0.0000]
# ================================================================ part4
#   in  p3       (900, 256)     first10= [0.0000 0.0059 0.0000 0.0000 0.0029 0.0000 0.0059 0.0029 0.0000 0.0000]
#   in  skip1    (900, 512)     first10= [0.0000 0.0000 0.0000 0.0000 0.3076 0.0000 0.0000 0.4561 0.0303 0.0898]
#   out DMA      (900, 4)       first10= [-0.0732 -0.0957  0.0469  0.0615 -0.0762 -0.0947  0.0518  0.0664 -0.0674
#  -0.0957]
# ================================================================
# end-to-end output shape: (900, 4)
# saved -> /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/_csim_data
#   x_input.npy     (900, 8, 8, 1)
#   y_keras.npy     (900, 4)
#   y_pred_hls.npy  (900, 4)

# %% [markdown]
# ## 9. (optional) per-layer diagnostic
# Set `RUN_DIAG=True` for a per-layer fixed-point signal-collapse bisect. Safe to skip.

# %%
# OPTIONAL — leave RUN_DIAG=False unless you want the per-layer fixed-point
# signal-collapse report. diag is split-independent (it probes the full model), so it is
# identical for both parts and is run on a tiny slice (it is slow).
if RUN_DIAG:
    hb.diag_bisect(full_model, PROBE_LAYERS, X_pool[:2])

# %% [markdown]
# ## 10. Streamer glue

# %%
# 4. streamer glue — compute dfx params (-> hb.dfx) and stitch the user-BD dispatcher TCL
hb.compute_streamer_glue()
hb.print_streamer_report()
# Out:
# [dfx-streamer] streams:
#   ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   | name       | shape              | region | alloc_phase | free_phase | precision | amt_entry_per_query | bits_per_entry | amt_banks_per_entry | amt_query_per_bankGrp |
#   ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   | a1         | (4, 4, 16)         |      0 |           0 |          1 |        16 |                  16 |            256 |                   4 |                   256 |
#   | skip1      | (8, 8, 8)          |      1 |           0 |          2 |        16 |                  64 |            128 |                   2 |                    64 |
#   | bneck      | (2, 2, 8)          |      1 |           1 |          2 |        16 |                   4 |            128 |                   2 |                  1024 |
#   | skip2      | (4, 4, 16)         |      1 |           1 |          2 |        16 |                  16 |            256 |                   4 |                   256 |
#   | p3         | (4, 4, 16)         |      0 |           2 |          3 |        16 |                  16 |            256 |                   4 |                   256 |
#   ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [dfx-streamer] dfx_streamers:
#   ────────────────────────────────────────────────────────────────────────────────────────────
#   | name           | region | amt_banks_per_entry | next_fin_phase | mul_factor |
#   ────────────────────────────────────────────────────────────────────────────────────────────
#       | stream       | amt_entry_per_query | amt_query_per_bankGrp | total_query |
#       ······················································································
#   | streamer_1     |      0 |                   4 |              3 |          4 |
#       ······················································································
#       | a1           |                  16 |                   256 |        1024 |
#       | p3           |                  16 |                   256 |        1024 |
#       ······················································································
#   | streamer_2     |      1 |                   2 |              2 |         15 |
#       ······················································································
#       | skip1        |                  64 |                    64 |         960 |
#       ······················································································
#   | streamer_3     |      1 |                   2 |              2 |          1 |
#       ······················································································
#       | bneck        |                   4 |                  1024 |        1024 |
#       ······················································································
#   | streamer_4     |      1 |                   4 |              2 |          4 |
#       ······················································································
#       | skip2        |                  16 |                   256 |        1024 |
#       ······················································································
#   ────────────────────────────────────────────────────────────────────────────────────────────
# [dfx-streamer] lowest total_query across all streams = 960
#
# === dfx_streamers (index 0 = DMA) ===
#   0 {'load_width': 4, 'store_width': 4, 'actual_width': 32, 'amount_row': 4096}
#   1 {'load_width': 32, 'store_width': 32, 'actual_width': 256, 'amount_row': 16384}
#   2 {'load_width': 16, 'store_width': 16, 'actual_width': 128, 'amount_row': 61440}
#   3 {'load_width': 16, 'store_width': 16, 'actual_width': 128, 'amount_row': 4096}
#   4 {'load_width': 32, 'store_width': 32, 'actual_width': 256, 'amount_row': 16384}
# === dfx_regions ===
#   0 {'load_streamers': [0, 3, 4], 'store_streamers': [1, 2]}
#   1 {'load_streamers': [1, 2], 'store_streamers': [0, 3, 4]}
# === rm_schemetics ===
#   region 0 rm 0: {'load_io_map': [(0, 0), (3, -1), (4, -1)], 'store_io_map': [(1, 0), (2, 1)]}
#   region 0 rm 1: {'load_io_map': [(0, -1), (3, 0), (4, 1)], 'store_io_map': [(1, 0), (2, -1)]}
#   region 1 rm 0: {'load_io_map': [(1, 0), (2, -1)], 'store_io_map': [(0, -1), (3, 0), (4, 1)]}
#   region 1 rm 1: {'load_io_map': [(1, 0), (2, 1)], 'store_io_map': [(0, 0), (3, -1), (4, -1)]}
#
# user_rm_build_tcl -> /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/create_dfx_region_user_bd.tcl

# %% [markdown]
# ## 11. Synthesis + FIFO optimization

# %%
# 3. synthesis + package (needs Vitis). Driven by the single SYNTH_MODE selector —
# 'synth' and 'fifo' are mutually exclusive ('fifo' = synth + FIFO-depth optimization,
# so it already runs C-synthesis; we never run plain synth on top of it).
# FIFO-depth optimization re-converts each partition (wiping + rewriting
# OUT_ROOT/<partition>) — the _csim_data files survive.
assert SYNTH_MODE in ('none', 'synth', 'fifo'), f"SYNTH_MODE must be 'none'|'synth'|'fifo', got {SYNTH_MODE!r}"
if SYNTH_MODE == 'synth':
    hb.synth_all()
elif SYNTH_MODE == 'fifo':
    hb.synth_all(fifo_opt=True)
else:
    print('SYNTH_MODE = none — skipping synthesis')
# Out:
# ================================================== fifo-opt part1
# WARNING: Invalid ReuseFactor=8 in layer "enc_conv1".Using ReuseFactor=9 instead. Valid ReuseFactor(s): 1,3,9,18,36,72.
# FIFO optimization completed
#
# ****** v++ v2023.2 (64-bit)
#   **** SW Build 4026344 on 2023-10-11-15:42:10
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# Running Dispatch Server on port: 35781
# INFO: [v++ 60-1548] Creating build summary session with primary output /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/vitis_unified_project.hlscompile_summary, at Fri Jun 19 16:31:16 2026
# INFO: [v++ 82-31] Launching vitis_hls: vitis_hls -nolog -run csynth -work_dir /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project -config /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg -cmdlineconfig /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/config.cmdline
#
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.2 (64-bit)
#   **** SW Build 4023990 on Oct 11 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2023.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2023.2/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'tanawin' on host 'kathryn2' (Linux_x86_64 version 6.8.0-124-generic) on Fri Jun 19 16:31:18 +07 2026
# INFO: [HLS 200-10] On os Ubuntu 22.04.5 LTS
# INFO: [HLS 200-10] In directory '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1'
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/config.cmdline
# INFO: [HLS 200-2005] Using work_dir /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project
# INFO: [HLS 200-1510] Running: open_project /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project -diskless
# INFO: [HLS 200-1510] Running: open_solution hls
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: apply_ini /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg
# INFO: [HLS 200-1465] Applying ini 'syn.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1_axi_stream.cpp' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(7)
# INFO: [HLS 200-10] Adding design file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1_axi_stream.cpp' to the project
# INFO: [HLS 200-1465] Applying ini 'syn.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(8)
# INFO: [HLS 200-10] Adding design file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp' to the project
# INFO: [HLS 200-1465] Applying ini 'syn.file_cflags=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1_axi_stream.cpp,-std=c++0x' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(9)
# INFO: [HLS 200-1465] Applying ini 'syn.file_cflags=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp,-std=c++0x' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(10)
# INFO: [HLS 200-1465] Applying ini 'tb.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/myproject_test.cpp' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(14)
# INFO: [HLS 200-10] Adding test bench file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/myproject_test.cpp' to the project
# INFO: [HLS 200-1465] Applying ini 'tb.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/weights' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(15)
# INFO: [HLS 200-10] Adding test bench file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/weights' to the project
# INFO: [HLS 200-1465] Applying ini 'tb.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/tb_data' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(16)
# INFO: [HLS 200-10] Adding test bench file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/tb_data' to the project
# INFO: [HLS 200-1465] Applying ini 'tb.file_cflags=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/myproject_test.cpp,-std=c++0x' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(17)
# INFO: [HLS 200-1465] Applying ini 'syn.top=p_part1_axi_stream' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(12)
# INFO: [HLS 200-1465] Applying ini 'flow_target=vivado' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(6)
# INFO: [HLS 200-1505] Using flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1465] Applying ini 'part=xck26-sfvc784-2LV-c' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(1)
# INFO: [HLS 200-1611] Setting target device to 'xck26-sfvc784-2LV-c'
# INFO: [HLS 200-1465] Applying ini 'clock=10ns' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(4)
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 10ns.
# INFO: [HLS 200-1465] Applying ini 'clock_uncertainty=12.5%' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(5)
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.25ns.
# INFO: [HLS 200-1465] Applying ini 'package.ip.version=1.0.0' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(19)
# INFO: [HLS 200-1465] Applying ini 'package.output.format=ip_catalog' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(20)
# INFO: [HLS 200-1465] Applying ini 'syn.compile.name_max_length=80' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(21)
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1465] Applying ini 'syn.schedule.enable_dsp_full_reg=0' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/hls_kernel_config.cfg(22)
# INFO: [HLS 200-1510] Running: apply_ini /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/config.cmdline
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/config.cmdline
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.09 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.1 seconds; current allocated memory: 274.355 MB.
# INFO: [HLS 200-10] Analyzing design file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp' ...
# WARNING: [HLS 207-5566] unexpected pragma argument 'softmax', expects function/operation (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_activation.h:402:36)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_dense_resource.h:34:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_dense_resource.h:109:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_dense_resource.h:192:9)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp:66:87)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp:66:91)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp:74:88)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp:74:92)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp:80:87)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp:80:91)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 6 issue(s) in file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1.cpp
# Resolution: For help on HLS 200-471 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-4074] variable templates are a C++14 extension (/tools/Xilinx/Vitis_HLS/2023.2/common/technology/autopilot/ap_axi_sdata.h:29:45)
# WARNING: [HLS 207-4074] variable templates are a C++14 extension (/tools/Xilinx/Vitis_HLS/2023.2/common/technology/autopilot/ap_axi_sdata.h:42:23)
# WARNING: [HLS 207-5292] unused parameter 'keep' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_helpers.h:329:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-5292] unused parameter 'data' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-5292] unused parameter 'res' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-5292] unused parameter 'weights' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-5292] unused parameter 'biases' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-5292] unused parameter 'data' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-5292] unused parameter 'res' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-5292] unused parameter 'weights' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-5292] unused parameter 'biases' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-10] Analyzing design file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/p_part1_axi_stream.cpp' ...
# WARNING: [HLS 207-4074] variable templates are a C++14 extension (/tools/Xilinx/Vitis_HLS/2023.2/common/technology/autopilot/ap_axi_sdata.h:29:45)
# WARNING: [HLS 207-4074] variable templates are a C++14 extension (/tools/Xilinx/Vitis_HLS/2023.2/common/technology/autopilot/ap_axi_sdata.h:42:23)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 17.54 seconds. CPU system time: 1.65 seconds. Elapsed time: 19.32 seconds; current allocated memory: 285.156 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 6,430 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 42,700 instructions in the design after the 'Unroll/Inline (step 1)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 17,620 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,558 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 10,477 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 9,020 instructions in the design after the 'Array/Struct (step 1)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 8,966 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 9,039 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,292 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 10,493 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 10,404 instructions in the design after the 'Performance (step 1)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 12,497 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 12,296 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 12,296 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 11,049 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 11,296 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details: /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/vitis_workspace/p_part1/vitis_unified_project/hls/syn/report/csynth_design_size.rpt
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::conv_2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv2d_stream.h:74:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::conv_2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv2d_stream.h:74:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::conv_2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv2d_stream.h:74:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::pooling2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config8>' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_pooling_stream.h:100:9)
# WARNING: [HLS 214-273] In function 'void nnet::shift_line_buffer<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config8>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type, config8::in_width> (*) [config8::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:219:0)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:54:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:62:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:66:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:70:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:78:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type (*) [config2::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*)' into 'void nnet::shift_line_buffer<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type, config2::in_width> (*) [config2::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:247:5)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_resource_rf_leq_nin<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_dense_resource.h:60:17)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseResource_rf_leq_nin<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>::dense(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type, config2::in_width> (*) [config2::n_chan], hls::stream<nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:288:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::conv_2d_buffer_resource_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*) (.17)' into 'void nnet::conv_2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<37, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv2d_stream.h:78:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:54:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:62:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:66:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:70:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config11>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:78:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type (*) [config4::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*)' into 'void nnet::shift_line_buffer<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type, config4::in_width> (*) [config4::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:247:5)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_resource_rf_leq_nin<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, config4_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4_mult::weight_t*, config4_mult::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_dense_resource.h:60:17)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseResource_rf_leq_nin<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, config4_mult>::dense(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type, config4::in_width> (*) [config4::n_chan], hls::stream<nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config4::weight_t*, config4::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:288:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::conv_2d_buffer_resource_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config4::weight_t*, config4::bias_t*) (.14)' into 'void nnet::conv_2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<40, 20, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config4::weight_t*, config4::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv2d_stream.h:78:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:54:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:62:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:66:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:70:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_padding_stream.h:78:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type (*) [config6::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*)' into 'void nnet::shift_line_buffer<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type, config6::in_width> (*) [config6::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:247:5)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_resource_rf_leq_nin<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>*, config6_mult::weight_t*, config6_mult::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_dense_resource.h:60:17)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseResource_rf_leq_nin<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>::dense(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type, config6::in_width> (*) [config6::n_chan], hls::stream<nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config6::weight_t*, config6::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:288:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::conv_2d_buffer_resource_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config6::weight_t*, config6::bias_t*) (.12)' into 'void nnet::conv_2d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<41, 21, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config6::weight_t*, config6::bias_t*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv2d_stream.h:78:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_2d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config8>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type (*) [config8::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*)' into 'void nnet::shift_line_buffer<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config8>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, ap_shift_reg<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type, config8::in_width> (*) [config8::n_chan], nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*)' (/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part1/firmware/nnet_utils/nnet_conv_stream.h:247:5)
# ...
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'p_part4_axi_stream'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# WARNING: [RTGEN 206-101] Design contains AXI ports. Reset is fixed to synchronous and active low.
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_input_stream_0_V_data_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_input_stream_0_V_keep_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_input_stream_0_V_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_input_stream_1_V_data_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_input_stream_1_V_keep_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_input_stream_1_V_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_output_stream_0_V_data_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_output_stream_0_V_keep_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/axi_output_stream_0_V_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'p_part4_axi_stream/batch_size' to 's_axilite & ap_none'.
# INFO: [RTGEN 206-500] Setting interface mode on function 'p_part4_axi_stream' to 's_axilite & ap_ctrl_hs'.
# INFO: [RTGEN 206-100] Bundling port 'batch_size' and 'return' to AXI-Lite port control.
# WARNING: [HLS 200-656] Deadlocks can occur since process load_input_flat<512u,axis,array<ap_fixed<16,6,5,3,0>,8u>> is instantiated in a dataflow region with ap_ctrl_none or without start propagation and contains an auto-rewind pipeline.
# Resolution: For help on HLS 200-656 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-656.html
# INFO: [RTGEN 206-100] Finished creating RTL model for 'p_part4_axi_stream'.
# INFO: [RTMG 210-285] Implementing FIFO 'batch_size_c11_U(p_part4_axi_stream_fifo_w32_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'model_input_stream_0_U(p_part4_axi_stream_fifo_w256_d16_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'model_input_stream_1_U(p_part4_axi_stream_fifo_w128_d64_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'batch_size_c_U(p_part4_axi_stream_fifo_w32_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'model_output_stream_0_U(p_part4_axi_stream_fifo_w256_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_compute_U0_U(p_part4_axi_stream_start_for_compute_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_store_result_U0_U(p_part4_axi_stream_start_for_store_result_U0)' using Shift Registers.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.3 seconds. CPU system time: 0.03 seconds. Elapsed time: 0.32 seconds; current allocated memory: 819.844 MB.
# INFO: [HLS 200-111] Finished Generating all RTL models: CPU user time: 0.84 seconds. CPU system time: 0.12 seconds. Elapsed time: 1.03 seconds; current allocated memory: 820.973 MB.
# INFO: [HLS 200-111] Finished Updating report files: CPU user time: 2.36 seconds. CPU system time: 0.07 seconds. Elapsed time: 2.43 seconds; current allocated memory: 840.254 MB.
# INFO: [VHDL 208-304] Generating VHDL RTL for p_part4_axi_stream.
# INFO: [VLOG 209-307] Generating Verilog RTL for p_part4_axi_stream.
# INFO: [HLS 200-790] **** Loop Constraint Status: All loop constraints were satisfied.
# INFO: [HLS 200-789] **** Estimated Fmax: 122.92 MHz
# INFO: [HLS 200-111] Finished Command csynth_design CPU user time: 70.75 seconds. CPU system time: 4.8 seconds. Elapsed time: 79.01 seconds; current allocated memory: 567.910 MB.
# INFO: [HLS 200-1510] Running: export_design -flow none -format ip_catalog
# INFO: [IMPL 213-8] Exporting RTL as a Vivado IP.
#
# ****** Vivado v2023.2 (64-bit)
#   **** SW Build 4029153 on Fri Oct 13 20:13:54 MDT 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# Sourcing tcl script '/home/tanawin/.Xilinx/Vivado/Vivado_init.tcl'
# source run_ippack.tcl -notrace
# ipx::create_core: Time (s): cpu = 00:00:12 ; elapsed = 00:00:13 . Memory (MB): peak = 1371.004 ; gain = 25.836 ; free physical = 901 ; free virtual = 62108
# INFO: [IP_Flow 19-234] Refreshing IP repositories
# INFO: [IP_Flow 19-1704] No user IP repositories specified
# INFO: [IP_Flow 19-2313] Loaded Vivado IP repository '/tools/Xilinx/Vivado/2023.2/data/ip'.
# INFO: [Common 17-206] Exiting Vivado at Fri Jun 19 17:05:30 2026...
# INFO: [HLS 200-802] Generated output file vitis_unified_project/p_part4_axi_stream.zip
# INFO: [HLS 200-111] Finished Command export_design CPU user time: 52.19 seconds. CPU system time: 1.73 seconds. Elapsed time: 59.19 seconds; current allocated memory: 11.336 MB.
# INFO: [HLS 200-1510] Running: close_project
# INFO: [HLS 200-112] Total CPU user time: 125.42 seconds. Total CPU system time: 6.92 seconds. Total elapsed time: 140.76 seconds; peak allocated memory: 853.602 MB.
# INFO: [Common 17-206] Exiting vitis_hls at Fri Jun 19 17:05:33 2026...
# INFO: [v++ 60-791] Total elapsed time: 0h 2m 24s
#
# ****** vitis-run v2023.2 (64-bit)
#   **** SW Build 4026344 on 2023-10-11-15:42:10
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# Running Dispatch Server on port: 43901
# INFO: [vitis-run 60-1548] Creating build summary session with primary output /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project/vitis_unified_project.hlsrun_package_summary, at Fri Jun 19 17:05:38 2026
# INFO: [vitis-run 82-31] Launching vitis_hls: vitis_hls -nolog -run package -work_dir /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project -config /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg -cmdlineconfig /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project/hls/config.cmdline
#
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.2 (64-bit)
#   **** SW Build 4023990 on Oct 11 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2023.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2023.2/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'tanawin' on host 'kathryn2' (Linux_x86_64 version 6.8.0-124-generic) on Fri Jun 19 17:05:40 +07 2026
# INFO: [HLS 200-10] On os Ubuntu 22.04.5 LTS
# INFO: [HLS 200-10] In directory '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4'
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project/hls/config.cmdline
# INFO: [HLS 200-2005] Using work_dir /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project
# INFO: [HLS 200-1510] Running: open_project /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project -diskless
# INFO: [HLS 200-1510] Running: open_solution hls
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: apply_ini /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg
# INFO: [HLS 200-1465] Applying ini 'syn.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/p_part4_axi_stream.cpp' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(7)
# INFO: [HLS 200-10] Adding design file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/p_part4_axi_stream.cpp' to the project
# INFO: [HLS 200-1465] Applying ini 'syn.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/p_part4.cpp' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(8)
# INFO: [HLS 200-10] Adding design file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/p_part4.cpp' to the project
# INFO: [HLS 200-1465] Applying ini 'syn.file_cflags=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/p_part4_axi_stream.cpp,-std=c++0x' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(9)
# INFO: [HLS 200-1465] Applying ini 'syn.file_cflags=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/p_part4.cpp,-std=c++0x' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(10)
# INFO: [HLS 200-1465] Applying ini 'tb.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/myproject_test.cpp' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(14)
# INFO: [HLS 200-10] Adding test bench file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/myproject_test.cpp' to the project
# INFO: [HLS 200-1465] Applying ini 'tb.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/weights' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(15)
# INFO: [HLS 200-10] Adding test bench file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/firmware/weights' to the project
# INFO: [HLS 200-1465] Applying ini 'tb.file=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/tb_data' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(16)
# INFO: [HLS 200-10] Adding test bench file '/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/tb_data' to the project
# INFO: [HLS 200-1465] Applying ini 'tb.file_cflags=/media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/myproject_test.cpp,-std=c++0x' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(17)
# INFO: [HLS 200-1465] Applying ini 'syn.top=p_part4_axi_stream' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(12)
# INFO: [HLS 200-1465] Applying ini 'flow_target=vivado' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(6)
# INFO: [HLS 200-1505] Using flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1465] Applying ini 'part=xck26-sfvc784-2LV-c' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(1)
# INFO: [HLS 200-1611] Setting target device to 'xck26-sfvc784-2LV-c'
# INFO: [HLS 200-1465] Applying ini 'clock=10ns' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(4)
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 10ns.
# INFO: [HLS 200-1465] Applying ini 'clock_uncertainty=12.5%' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(5)
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.25ns.
# INFO: [HLS 200-1465] Applying ini 'package.ip.version=1.0.0' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(19)
# INFO: [HLS 200-1465] Applying ini 'package.output.format=ip_catalog' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(20)
# INFO: [HLS 200-1465] Applying ini 'syn.compile.name_max_length=80' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(21)
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1465] Applying ini 'syn.schedule.enable_dsp_full_reg=0' at /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/hls_kernel_config.cfg(22)
# INFO: [HLS 200-1510] Running: apply_ini /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project/hls/config.cmdline
# INFO: [HLS 200-1909] Reading HLS ini file /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/hls4ml_dfx_out/part_2/part4/vitis_workspace/p_part4/vitis_unified_project/hls/config.cmdline
# INFO: [HLS 200-1510] Running: export_design -flow none
# INFO: [IMPL 213-8] Exporting RTL as a Vivado IP.
#
# ****** Vivado v2023.2 (64-bit)
#   **** SW Build 4029153 on Fri Oct 13 20:13:54 MDT 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# Sourcing tcl script '/home/tanawin/.Xilinx/Vivado/Vivado_init.tcl'
# source run_ippack.tcl -notrace
# ipx::create_core: Time (s): cpu = 00:00:10 ; elapsed = 00:00:10 . Memory (MB): peak = 1386.008 ; gain = 0.023 ; free physical = 1531 ; free virtual = 62630
# INFO: [IP_Flow 19-234] Refreshing IP repositories
# INFO: [IP_Flow 19-1704] No user IP repositories specified
# INFO: [IP_Flow 19-2313] Loaded Vivado IP repository '/tools/Xilinx/Vivado/2023.2/data/ip'.
# INFO: [Common 17-206] Exiting Vivado at Fri Jun 19 17:06:34 2026...
# INFO: [HLS 200-802] Generated output file vitis_unified_project/p_part4_axi_stream.zip
# INFO: [HLS 200-111] Finished Command export_design CPU user time: 45.82 seconds. CPU system time: 6.99 seconds. Elapsed time: 54.22 seconds; current allocated memory: 21.848 MB.
# INFO: [HLS 200-1510] Running: close_project
# INFO: [HLS 200-112] Total CPU user time: 48.94 seconds. Total CPU system time: 7.43 seconds. Total elapsed time: 57.47 seconds; peak allocated memory: 296.055 MB.
# INFO: [Common 17-206] Exiting vitis_hls at Fri Jun 19 17:06:37 2026...
# INFO: [vitis-run 60-791] Total elapsed time: 0h 1m 1s
# synthesis done (fifo-optimized)

# %% [markdown]
# ## 12. Hardware build

# %%
# 5. dfx4ml Vivado hardware build (board / user_repo / tcl / dfx / rm_width / vivado
# are all pulled from hb).
hw = None
if RUN_HWBUILD:
    hw = HwBuildHelper(
        build_folder_path  = f'./build_prj_{PART_TAG}',
        dfx_root_path      = '.',
        export_folder_path = f'./export_{PART_TAG}',
        req_gen_ip         = 1,
        num_core           = 4,
        clk_frq            = 99999001,
        test_mode          = 0,          # user kernels
        hls4ml_build       = hb,         # config pulled from hb
    )
    hw.run_build()
    hw.package_export_files()
    print('hardware build complete -> ./export/hw')
# Out:
# Running Vivado with /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/build_prj_part_2/run_build.tcl...
#
# ****** Vivado v2023.2 (64-bit)
#   **** SW Build 4029153 on Fri Oct 13 20:13:54 MDT 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# start_gui
# INFO: [Common 17-206] Exiting Vivado at Fri Jun 19 19:17:32 2026...
# Warning: Removing BASEVALUE from line:         <MEMRANGE ADDRESSBLOCK="Reg" BASENAME="C_BASEADDR" BASEVALUE="0xA0010000" HIGHNAME="C_HIGHADDR" HIGHVALUE="0xA001FFFF" INSTANCE="dfx_unified_0" IS_DATA="TRUE" IS_INSTRUCTION="TRUE" MASTERBUSINTERFACE="M_AXI_HPM0_FPD" MEMTYPE="REGISTER" SLAVEBUSINTERFACE="S_AXI"/>
#
# Warning: Removing BASEVALUE from line:         <MEMRANGE ADDRESSBLOCK="Reg" BASENAME="C_BASEADDR" BASEVALUE="0xA0020000" HIGHNAME="C_HIGHADDR" HIGHVALUE="0xA002FFFF" INSTANCE="dfx_unified_0" IS_DATA="TRUE" IS_INSTRUCTION="TRUE" MASTERBUSINTERFACE="M_AXI_HPM0_FPD" MEMTYPE="REGISTER" SLAVEBUSINTERFACE="S_AXI"/>
#
# Warning: Removing BASEVALUE from line:         <MEMRANGE ADDRESSBLOCK="Reg" BASENAME="C_BASEADDR" BASEVALUE="0xA0030000" HIGHNAME="C_HIGHADDR" HIGHVALUE="0xA003FFFF" INSTANCE="dfx_unified_0" IS_DATA="TRUE" IS_INSTRUCTION="TRUE" MASTERBUSINTERFACE="M_AXI_HPM0_FPD" MEMTYPE="REGISTER" SLAVEBUSINTERFACE="S_AXI_LITE"/>
#
# Warning: Removing BASEVALUE from line:         <MEMRANGE ADDRESSBLOCK="reg0" BASENAME="C_BASEADDR" BASEVALUE="0xA0040000" HIGHNAME="C_HIGHADDR" HIGHVALUE="0xA004FFFF" INSTANCE="dfx_unified_0" IS_DATA="TRUE" IS_INSTRUCTION="TRUE" MASTERBUSINTERFACE="M_AXI_HPM0_FPD" MEMTYPE="REGISTER" SLAVEBUSINTERFACE="S_AXI"/>
#
# Warning: Removing BASEVALUE from line:         <MEMRANGE ADDRESSBLOCK="reg0" BASENAME="C_BASEADDR" BASEVALUE="0xA0050000" HIGHNAME="C_HIGHADDR" HIGHVALUE="0xA005FFFF" INSTANCE="dfx_pr_region_0_0" IS_DATA="TRUE" IS_INSTRUCTION="TRUE" MASTERBUSINTERFACE="M_AXI_HPM0_FPD" MEMTYPE="REGISTER" SLAVEBUSINTERFACE="S_AXI"/>
#
# Warning: Removing BASEVALUE from line:         <MEMRANGE ADDRESSBLOCK="reg0" BASENAME="C_BASEADDR" BASEVALUE="0xA0060000" HIGHNAME="C_HIGHADDR" HIGHVALUE="0xA006FFFF" INSTANCE="dfx_pr_region_1_0" IS_DATA="TRUE" IS_INSTRUCTION="TRUE" MASTERBUSINTERFACE="M_AXI_HPM0_FPD" MEMTYPE="REGISTER" SLAVEBUSINTERFACE="S_AXI"/>
#
# hardware build complete -> ./export/hw

# %% [markdown]
# ## 13. Software build

# %%
# 6. PYNQ software build — packages the drivers + data folder into ./export
if RUN_HWBUILD:
    SwBuildHelper(hw_builder=hw).package_export_file()
    print('software build complete -> ./export')
# Out:
# software build complete -> ./export

# %% [markdown]
# ## 14. Stage data + board notebook into ./export
# Copies the csim reference arrays into `export/data/` and drops the matching board-side test notebook beside `export/`.

# %%
# 7. stage the csim reference data + the matching board-side test notebook into ./export.
# On the KV260 the export folder is the project dir: the board notebook loads
# data/x_input.npy and compares the hardware output to data/y_pred_hls.npy.
EXPORT_DIR  = REPO / f'export_{PART_TAG}'
EXPORT_DATA = EXPORT_DIR / 'data'
EXPORT_DATA.mkdir(parents=True, exist_ok=True)

for fname in ('x_input.npy', 'y_keras.npy', 'y_pred_hls.npy'):
    src = CSIM_DATA_DIR / fname
    if src.exists():
        shutil.copy(src, EXPORT_DATA / fname)
        print('copied', fname, '->', EXPORT_DATA / fname)

BOARD_NB = REPO / 'example' / 'tutorial' / 'hls4ml_2_region_4_rm.ipynb'
shutil.copy(BOARD_NB, EXPORT_DIR / BOARD_NB.name)
print('copied board notebook ->', EXPORT_DIR / BOARD_NB.name)
# Out:
# copied x_input.npy -> /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/export_part_2/data/x_input.npy
# copied y_keras.npy -> /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/export_part_2/data/y_keras.npy
# copied y_pred_hls.npy -> /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/export_part_2/data/y_pred_hls.npy
# copied board notebook -> /media/tanawin/tanawin1701e/project8/dfx4ml/dfx4ml_code/export_part_2/hls4ml_2_region_4_rm.ipynb

# %% [markdown]
# ## 15. Copy to the KV260 PYNQ board
# Copy the packaged `export_part_2/` (hardware bitstreams, PYNQ drivers, csim data, and the board notebook) to the KV260 **yourself**, then run the board notebook (`hls4ml_2_region_4_rm.ipynb`) there.
#
# From a terminal on this machine (replace the host/user/dest with your board's — KV260 PYNQ default login is `ubuntu`/`ubuntu`):
#
# ```bash
# scp -r export_part_2/. ubuntu@<board-ip>:/home/ubuntu/jupyter_notebooks/part_2
# ```
